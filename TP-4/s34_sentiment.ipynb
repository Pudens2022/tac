# %% [markdown]
# # Sentiment analysis avec Textblob-FR

# %% [markdown]
# Documentation: https://textblob.readthedocs.io/en/dev/

# %% [markdown]
# ## Imports

# %%
import sys
from textblob import Blobber
from textblob_fr import PatternTagger, PatternAnalyzer

# %% [markdown]
# ## Fonction

# %%
tb = Blobber(pos_tagger=PatternTagger(), analyzer=PatternAnalyzer())

def get_sentiment(input_text):
    blob = tb(input_text)
    polarity, subjectivity = blob.sentiment
    polarity_perc = f"{100*abs(polarity):.0f}"
    subjectivity_perc = f"{100*subjectivity:.0f}"
    if polarity > 0:
        polarity_str = f"{polarity_perc}% positive"
    elif polarity < 0:
        polarity_str = f"{polarity_perc}% negative"
    else:
        polarity_str = "neutral"
    if subjectivity > 0:
        subjectivity_str = f"{subjectivity}% subjective"
    else:
        subjectivity_str = "perfectly objective"
    #print(f"{polarity_str} {subjectivity_str}.")
    print(polarity, subjectivity)

# %%
# Lister les fichiers des années 1929-1939
data_path = "../data/camille_crise_economique_des_annees_1930/"
#txt_path = '../data/txt'
txts = [f for f in os.listdir(data_path)]
# txts

# %%
# Stocker le contenu de ces fichiers dans une liste
i=0
for txt in txts:
    f = open(os.path.join(data_path, txt), 'r', encoding="utf-8")
    #print(txt)
    content_list = f.readlines()
    get_sentiment(content_list[0])
# Out:
# 0.08407282366071418 0.1507700892857145
# 0.0644952631578947 0.3169515789473672
# 0.08848543689320378 0.28121359223300946
# 0.08606447963800905 0.307409502262443
# 0.09607089757709254 0.19473568281938347
# 0.05692236467236461 0.20384615384615404
# 0.08426558242506803 0.20506811989100843
# 0.08044117647058827 0.38904411764705876
# 0.09067275747508309 0.19880398671096386
# 0.08754175420168074 0.17284663865546226
# 0.07138877338877335 0.3279417879417871
# 0.1187197075208913 0.21616991643454025
# 0.08050000000000002 0.22057534246575353
# 0.08023136467889903 0.1730504587155966
# 0.09857530864197528 0.1933456790123457
# 0.03843908227848104 0.19610759493670918
# 0.04883202099737537 0.1705643044619426
# 0.08248219584569737 0.20548961424332365
# 0.07141648822269811 0.22958244111349044
# 0.08476036432160804 0.21972361809045227
# 0.05814832535885165 0.24315789473684232
# 0.0763790760869565 0.19750000000000006
# 0.11148854961832057 0.18564885496183223
# 0.03841008771929826 0.20570175438596494
# ...

# %% [markdown]
# ## Analyser le sentiment de dix phrases choisies arbitrairement

# %%
get_sentiment("Les non-ferreux n’échappent pas à l'allure assez maussade du marché.")
# Out:
# 0.0 0.0

# %%
get_sentiment("j’ai l'espoir qu'en ce qui nous concerne, il en sera également ainsi.")
# Out:
# 0.2 0.35

# %%
get_sentiment("Le prévenu niait tous ces faits.")
# Out:
# 0.22 0.1

# %%
get_sentiment("un gourmet aime choisir ce qu’il savoure.")
# Out:
# 0.6 0.6

# %%
get_sentiment("Les malades sont obligés de vivre dans les îles Aremaca et Ariaia, sur le fleuve Solimos.")
# Out:
# -0.35 0.4

# %%
get_sentiment("La réussite d’une telle campagne dépend évidemment de la participation du plus grand nombre.")
# Out:
# 0.29500000000000004 0.33

# %%
get_sentiment("Dans nos nouvelles collections, vous trouverez le vêtement qui répond à vos goûts et à vos exigences.")
# Out:
# 0.1 0.25

# %%
get_sentiment("Cette ambiguïté gauchit quelque peu les conclusions de l’écrivain.")
# Out:
# -0.04 0.25

# %%
get_sentiment("Présentés avec humour par leur président, M. Jardez. les chansonniers de la compagnie rivalisèrent dans leur talent d’auteurs et d’interprètes.")
# Out:
# 0.3 0.05

# %%
get_sentiment("La bagarre fut très belle qui opposa deux œuvres diamétralement opposées.")
# Out:
# 0.45 0.6
